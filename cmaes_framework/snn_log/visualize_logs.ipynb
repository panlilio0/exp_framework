# %% [markdown]
# # Show activation level, spike train, and duty cycle for a specific neuron

# %%
import plots

neuron = 1

file_path = "latest_data.csv"  # <-- Update this
df = plots.load_logs(file_path)

xlim = 100

# Plot a neuron
plots.plot_neuron_logs(df, xlim, snn_id=neuron, layer='hidden', neuron_id=1)

# %% [markdown]
# # Plots for a whole SNN

# %%
import plots

df = plots.load_logs(file_path)

plots.plot_snn_spiketrains(df, xlim, snn_id=neuron)
plots.plot_snn_activation_levels(df, xlim, snn_id=neuron)
plots.plot_snn_dutycycles(df, xlim, snn_id=neuron)

# %%
plots.plot_fitness_over_time("latest_experiment")
# Out:
# Looking for run_*.csv files in: /Users/panlilio0/exp_framework/cmaes_framework/latest_experiment

# %%
plots.boxplot_last_generation_fitness("latest_experiment")
# Out:
# Looking for run_*.csv files in: /Users/panlilio0/exp_framework/cmaes_framework/latest_experiment
