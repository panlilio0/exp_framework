# %% [markdown]
# # Show activation level, spike train, and duty cycle for a specific neuron

# %%
import plots

file_path = "2025-04-09_12:25:39.csv"  # <-- Update this
df = plots.load_logs(file_path)

# Plot a neuron
plots.plot_neuron_logs(df, snn_id=3, layer='hidden', neuron_id=1)

# %% [markdown]
# # Plots for a whole SNN

# %%
import plots

file_path = "2025-04-09_12:41:07.csv"  # <-- Update this
df = plots.load_logs(file_path)

plots.plot_snn_spiketrains(df, snn_id=2)
plots.plot_snn_activation_levels(df, snn_id=2)
plots.plot_snn_dutycycles(df, snn_id=2)
