# %% [markdown]
# # Show activation level, spike train, and duty cycle for a specific neuron

# %%
from pathlib import Path
import plots
import os

snn = 2

file_path = "latest_log" # <-- Update this

if not file_path == "latest_log":
    file_path = Path(os.path.join("..", "data", "logs", file_path + ".csv"))
else:
    file_path = Path(os.path.join ("..", "data", file_path + ".csv"))

df = plots.load_logs(file_path)

xlim = 100

# Plot a neuron
# Why does layer='output' not work here?
plots.plot_neuron_logs(df, xlim, snn_id=(snn-1), layer='output', neuron_id=0)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 14
#      11 else:
#      12     file_path = Path(file_path + ".csv")
# ---> 14 df = plots.load_logs(file_path)
#      16 xlim = 100
#      18 # Plot a neuron
#      19 # Why does layer='output' not work here?
#
# File ~/Desktop/CSC/Ind-Study/exp_framework/cmaes_framework/exp_plots/plots.py:20, in load_logs(file_path)
#      18 def load_logs(file_path):
#      19     """Load CSV log data."""
# ---> 20     return pd.read_csv(file_path)
#
# File ~/Desktop/CSC/Ind-Study/exp_framework/.venv/lib/python3.10/site-packages/pandas/io/parsers/readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)
#    1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File ~/Desktop/CSC/Ind-Study/exp_framework/.venv/lib/python3.10/site-packages/pandas/io/parsers/readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File ~/Desktop/CSC/Ind-Study/exp_framework/.venv/lib/python3.10/site-packages/pandas/io/parsers/readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File ~/Desktop/CSC/Ind-Study/exp_framework/.venv/lib/python3.10/site-packages/pandas/io/parsers/readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File ~/Desktop/CSC/Ind-Study/exp_framework/.venv/lib/python3.10/site-packages/pandas/io/common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'latest_log.csv'

# %% [markdown]
# # Plots for a whole SNN

# %%
import plots

df = plots.load_logs(file_path)

plots.plot_snn_spiketrains(df, xlim, snn_id=(snn-1))
plots.plot_snn_activation_levels(df, xlim, snn_id=(snn-1))
plots.plot_snn_dutycycles(df, xlim, snn_id=(snn-1))

# %%
# genomes = "2025-04-25_14-22-29" # This can be replaced with a folder name from genomes or latest_genome
genomes = "latest_genome"

plots.plot_fitness_over_time(genomes)
# Out:
# /Users/jamesgaskell/Desktop/CSC/Ind-Study/exp_framework/cmaes_framework/data/genomes/2025-04-25_14-22-29
